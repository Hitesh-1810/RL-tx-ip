# %%
# !pip install gymnasium torch numpy matplotlib
# Out:
# Requirement already satisfied: gymnasium in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.3.0)
# Requirement already satisfied: torch in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.11.0)
# Requirement already satisfied: numpy in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.26.2)
# Requirement already satisfied: matplotlib in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.10.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gymnasium) (0.0.6)
# Requirement already satisfied: filelock in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: setuptools<82 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (69.0.2)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Hitesh Girase\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch) (3.0.3)
# [notice] A new release of pip is available: 26.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
import matplotlib.pyplot as plt

# %%
env = gym.make("CartPole-v1")

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

print("State size:", state_dim)
print("Action size:", action_dim)
# Out:
# State size: 4
# Action size: 2

# %%
GAMMA = 0.99
LR = 0.001
BATCH_SIZE = 64
MEMORY_SIZE = 10000

EPSILON = 1.0
EPSILON_DECAY = 0.995
EPSILON_MIN = 0.01

TARGET_UPDATE = 10
EPISODES = 200

# %%
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim)
        )

    def forward(self, x):
        return self.fc(x)

# %%
memory = deque(maxlen=MEMORY_SIZE)

def store_transition(state, action, reward, next_state, done):
    memory.append((state, action, reward, next_state, done))

# %%
policy_net = DQN()
target_net = DQN()

target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LR)
loss_fn = nn.MSELoss()

# %%
def select_action(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        state = torch.FloatTensor(state).unsqueeze(0)
        return torch.argmax(policy_net(state)).item()

# %%
def train():
    if len(memory) < BATCH_SIZE:
        return

    batch = random.sample(memory, BATCH_SIZE)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(states)
    actions = torch.LongTensor(actions).unsqueeze(1)
    rewards = torch.FloatTensor(rewards)
    next_states = torch.FloatTensor(next_states)
    dones = torch.FloatTensor(dones)

    current_q = policy_net(states).gather(1, actions).squeeze()
    next_q = target_net(next_states).max(1)[0]

    target_q = rewards + GAMMA * next_q * (1 - dones)

    loss = loss_fn(current_q, target_q.detach())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
rewards_list = []
epsilon = EPSILON

for episode in range(EPISODES):
    state, _ = env.reset()
    total_reward = 0

    while True:
        action = select_action(state, epsilon)
        next_state, reward, done, _, _ = env.step(action)

        store_transition(state, action, reward, next_state, done)
        train()

        state = next_state
        total_reward += reward

        if done:
            break

    rewards_list.append(total_reward)

    epsilon = max(EPSILON_MIN, epsilon * EPSILON_DECAY)

    if episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

    print(f"Episode {episode}, Reward: {total_reward}")
# Out:
# Episode 0, Reward: 13.0
# Episode 1, Reward: 14.0
# Episode 2, Reward: 41.0
# Episode 3, Reward: 28.0
# Episode 4, Reward: 11.0
# Episode 5, Reward: 32.0
# Episode 6, Reward: 19.0
# Episode 7, Reward: 24.0
# Episode 8, Reward: 28.0
# Episode 9, Reward: 19.0
# Episode 10, Reward: 33.0
# Episode 11, Reward: 17.0
# Episode 12, Reward: 11.0
# Episode 13, Reward: 18.0
# Episode 14, Reward: 24.0
# Episode 15, Reward: 13.0
# Episode 16, Reward: 15.0
# Episode 17, Reward: 13.0
# Episode 18, Reward: 12.0
# Episode 19, Reward: 12.0
# Episode 20, Reward: 39.0
# Episode 21, Reward: 44.0
# Episode 22, Reward: 11.0
# Episode 23, Reward: 41.0
# Episode 24, Reward: 44.0
# Episode 25, Reward: 40.0
# Episode 26, Reward: 11.0
# Episode 27, Reward: 21.0
# Episode 28, Reward: 15.0
# Episode 29, Reward: 14.0
# Episode 30, Reward: 28.0
# Episode 31, Reward: 51.0
# Episode 32, Reward: 45.0
# Episode 33, Reward: 24.0
# Episode 34, Reward: 69.0
# Episode 35, Reward: 36.0
# Episode 36, Reward: 23.0
# Episode 37, Reward: 22.0
# Episode 38, Reward: 19.0
# Episode 39, Reward: 11.0
# Episode 40, Reward: 23.0
# Episode 41, Reward: 21.0
# Episode 42, Reward: 15.0
# Episode 43, Reward: 16.0
# Episode 44, Reward: 16.0
# Episode 45, Reward: 21.0
# Episode 46, Reward: 39.0
# Episode 47, Reward: 56.0
# Episode 48, Reward: 25.0
# Episode 49, Reward: 33.0
# Episode 50, Reward: 75.0
# Episode 51, Reward: 23.0
# Episode 52, Reward: 37.0
# Episode 53, Reward: 61.0
# Episode 54, Reward: 40.0
# Episode 55, Reward: 37.0
# Episode 56, Reward: 24.0
# Episode 57, Reward: 42.0
# Episode 58, Reward: 13.0
# Episode 59, Reward: 48.0
# Episode 60, Reward: 30.0
# Episode 61, Reward: 14.0
# Episode 62, Reward: 28.0
# Episode 63, Reward: 46.0
# Episode 64, Reward: 45.0
# Episode 65, Reward: 33.0
# Episode 66, Reward: 14.0
# Episode 67, Reward: 75.0
# Episode 68, Reward: 28.0
# Episode 69, Reward: 50.0
# Episode 70, Reward: 31.0
# Episode 71, Reward: 25.0
# Episode 72, Reward: 41.0
# Episode 73, Reward: 19.0
# Episode 74, Reward: 14.0
# Episode 75, Reward: 33.0
# Episode 76, Reward: 57.0
# Episode 77, Reward: 15.0
# Episode 78, Reward: 46.0
# Episode 79, Reward: 13.0
# Episode 80, Reward: 66.0
# Episode 81, Reward: 14.0
# Episode 82, Reward: 32.0
# Episode 83, Reward: 30.0
# Episode 84, Reward: 65.0
# Episode 85, Reward: 25.0
# Episode 86, Reward: 20.0
# Episode 87, Reward: 20.0
# Episode 88, Reward: 42.0
# Episode 89, Reward: 110.0
# Episode 90, Reward: 35.0
# Episode 91, Reward: 70.0
# Episode 92, Reward: 75.0
# Episode 93, Reward: 21.0
# Episode 94, Reward: 16.0
# Episode 95, Reward: 20.0
# Episode 96, Reward: 75.0
# Episode 97, Reward: 15.0
# Episode 98, Reward: 125.0
# Episode 99, Reward: 103.0
# Episode 100, Reward: 59.0
# Episode 101, Reward: 31.0
# Episode 102, Reward: 32.0
# Episode 103, Reward: 60.0
# Episode 104, Reward: 12.0
# Episode 105, Reward: 11.0
# Episode 106, Reward: 55.0
# Episode 107, Reward: 32.0
# Episode 108, Reward: 15.0
# Episode 109, Reward: 72.0
# Episode 110, Reward: 139.0
# Episode 111, Reward: 19.0
# Episode 112, Reward: 26.0
# Episode 113, Reward: 117.0
# Episode 114, Reward: 87.0
# Episode 115, Reward: 60.0
# Episode 116, Reward: 37.0
# Episode 117, Reward: 42.0
# Episode 118, Reward: 19.0
# Episode 119, Reward: 94.0
# Episode 120, Reward: 102.0
# Episode 121, Reward: 95.0
# Episode 122, Reward: 149.0
# Episode 123, Reward: 20.0
# Episode 124, Reward: 91.0
# Episode 125, Reward: 61.0
# Episode 126, Reward: 88.0
# Episode 127, Reward: 20.0
# Episode 128, Reward: 53.0

# %%
plt.plot(rewards_list)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("DQN Training Performance")
plt.show()

# %%
moving_avg = []

for i in range(len(rewards_list)):
    moving_avg.append(np.mean(rewards_list[max(0, i-9):i+1]))

plt.figure(figsize=(10,5))

plt.plot(rewards_list, label="Rewards")
plt.plot(moving_avg, label="Moving Average")

plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.title("DQN Training Performance")
plt.legend()
plt.grid()

plt.show()

# %%
state, _ = env.reset()
done = False

while not done:
    state_tensor = torch.FloatTensor(state).unsqueeze(0)
    action = torch.argmax(policy_net(state_tensor)).item()
    state, _, done, _, _ = env.step(action)

env.close()
